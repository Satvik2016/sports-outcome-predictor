# %%
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd
import time

all_games = []

for season_year in range(2012, 2025):
    season_str = f"{season_year}-{str(season_year+1)[-2:]}"
    print(f"Pulling {season_str}...")
    try:
        gamefinder = leaguegamefinder.LeagueGameFinder(
            season_nullable=season_str,
            league_id_nullable='00'
        )
        games = gamefinder.get_data_frames()[0]
        all_games.append(games)
        time.sleep(1) 
    except Exception as e:
        print(f"  Skipped {season_str}: {e}")
        continue

df = pd.concat(all_games, ignore_index=True)


df = df.rename(columns={
    'TEAM_ABBREVIATION': 'team',
    'GAME_DATE':         'date',
    'MATCHUP':           'matchup',
    'WL':                'result_str',
    'PTS':               'team_score',
})


df['result'] = (df['result_str'] == 'W').astype(int)


df['is_home'] = df['matchup'].apply(lambda x: 0 if '@' in x else 1)
df['opponent'] = df['matchup'].apply(lambda x: x.split()[-1])


df.to_csv('data/raw/nba_games.csv', index=False)
print(f"Done! Saved {len(df)} rows.")
print(df[['team','date','opponent','is_home','team_score','result']].head(10))
# Out:
# Pulling 2012-13...
# Pulling 2013-14...
# Pulling 2014-15...
# Pulling 2015-16...
# Pulling 2016-17...
# Pulling 2017-18...
# Pulling 2018-19...
# Pulling 2019-20...
# Pulling 2020-21...
# Pulling 2021-22...
# Pulling 2022-23...
# Pulling 2023-24...
# Pulling 2024-25...
# Done! Saved 35995 rows.
#   team        date opponent  is_home  team_score  result
# 0  SAS  2013-06-20      MIA        0          88       0
# 1  MIA  2013-06-20      SAS        1          95       1
# 2  SAS  2013-06-18      MIA        0         100       0
# 3  MIA  2013-06-18      SAS        1         103       1
# 4  MIA  2013-06-16      SAS        0         104       0
# 5  SAS  2013-06-16      MIA        1         114       1
# 6  MIA  2013-06-13      SAS        0         109       1
# 7  SAS  2013-06-13      MIA        1          93       0
# 8  MIA  2013-06-11      SAS        0          77       0
# 9  SAS  2013-06-11      MIA        1         113       1
